# %%
import pandas as pd
import numpy as np

# %%
# Create an embeeding 
df_items_master = pd.read_csv("Item_master.csv")
print("The number of rows and columns : ", df_items_master.shape)
# Out:
# The number of rows and columns :  (5931, 56)

# %%
df_items_master.columns
# Out:
# Index(['item', 'description', 'overview', 'matlType', 'MaterialStatus',
#        'Stocked', 'organizationCode', 'Grade', 'specCode', 'Shape', 'ppapItem',
#        'itemType', 'diameterMaximum', 'diameterMininum', 'ThicknessMaximum',
#        'WidthMinimum', 'crossCornerMaximum', 'crossCornerMinimum',
#        'widthMaximum', 'widthMinimum', 'cornerRadius', 'lengthMaximum',
#        'lengthMinimum', 'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth',
#        'stressRelieved', 'lpAnnealed', 'ground', 'shearOne', 'shearBoth',
#        'spheriodizeAnneal', 'polished', 'chamfered1End', 'chamferedBoth',
#        'coldDrawn', 'faceOneEnd', 'faceBoth', 'deburr', 'demagnetize',
#        'oneHeatOnly', 'markHeatOne', 'markHeatBoth', 'annealed', 'pickled',
#        'normalized', 'straighten', 'rollMark', 'rollMarkNote', 'roto',
#        'magnetic', 'ultrasonicTest', 'eddyCurrent', 'specDesc', 'grainType'],
#       dtype='object')

# %%
# List of columns to keep
columns_to_keep = [
        'matlType', 'MaterialStatus',
       'Stocked', 'organizationCode', 'Grade', 'specCode', 'Shape', 'ppapItem',
       'itemType', 'diameterMaximum', 'diameterMininum', 'ThicknessMaximum',
       'WidthMinimum', 'crossCornerMaximum', 'crossCornerMinimum',
       'widthMaximum', 'widthMinimum', 'cornerRadius', 'lengthMaximum',
       'lengthMinimum', 'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth',
       'stressRelieved', 'lpAnnealed', 'ground', 'shearOne', 'shearBoth',
       'spheriodizeAnneal', 'polished', 'chamfered1End', 'chamferedBoth',
       'coldDrawn', 'faceOneEnd', 'faceBoth', 'deburr', 'demagnetize',
       'oneHeatOnly', 'markHeatOne', 'markHeatBoth', 'annealed', 'pickled',
       'normalized', 'straighten', 'rollMark', 'roto',
       'magnetic', 'ultrasonicTest', 'eddyCurrent'
]

# Create new DataFrame with only selected columns
df_selected = df_items_master[columns_to_keep]

# %%
# List of columns to get value counts for
columns_to_check = [
    'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth', 'stressRelieved',
    'lpAnnealed', 'ground', 'shearOne', 'shearBoth', 'spheriodizeAnneal',
    'polished', 'chamfered1End', 'chamferedBoth', 'coldDrawn', 'faceOneEnd',
    'faceBoth', 'deburr', 'demagnetize', 'oneHeatOnly', 'markHeatOne',
    'markHeatBoth', 'annealed', 'pickled', 'normalized', 'straighten',
    'rollMark', 'roto', 'magnetic', 'ultrasonicTest', 'eddyCurrent'
]

# Loop through each column and print value counts
for col in columns_to_check:
    print(f"\nValue counts for column: {col}")
    print(df_selected[col].value_counts(dropna=False))
# Out:
# Value counts for column: quenchTemper
# quenchTemper
# N    5894
# Y      37
# Name: count, dtype: int64
#
# Value counts for column: turned
# turned
# N    5404
# Y     527
# Name: count, dtype: int64
#
# Value counts for column: sawCut1End
# sawCut1End
# N    5800
# Y     131
# Name: count, dtype: int64
#
# Value counts for column: sawcutBoth
# sawcutBoth
# N    5663
# Y     268
# Name: count, dtype: int64
#
# Value counts for column: stressRelieved
# stressRelieved
# N    5792
# Y     139
# Name: count, dtype: int64
#
# Value counts for column: lpAnnealed
# lpAnnealed
# N    5522
# Y     409
# Name: count, dtype: int64
#
# Value counts for column: ground
# ground
# N    5357
# Y     574
# Name: count, dtype: int64
#
# Value counts for column: shearOne
# shearOne
# N    5931
# Name: count, dtype: int64
#
# Value counts for column: shearBoth
# shearBoth
# N    5929
# Y       2
# Name: count, dtype: int64
#
# Value counts for column: spheriodizeAnneal
# spheriodizeAnneal
# N    5908
# ...

# %%
# List of columns to process
columns_to_process = ['Stocked', 'ppapItem',
    'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth', 'stressRelieved',
    'lpAnnealed', 'ground', 'shearOne', 'shearBoth', 'spheriodizeAnneal',
    'polished', 'chamfered1End', 'chamferedBoth', 'coldDrawn', 'faceOneEnd',
    'faceBoth', 'deburr', 'demagnetize', 'oneHeatOnly', 'markHeatOne',
    'markHeatBoth', 'annealed', 'pickled', 'normalized', 'straighten',
    'rollMark', 'roto', 'magnetic', 'ultrasonicTest', 'eddyCurrent'
]

# Replace 'Y' with column name, 'N' with empty string
for col in columns_to_process:
    df_selected[col] = df_selected[col].apply(lambda x: col if x == 'Y' else '')

# Optional: To view result
df_selected[columns_to_process].head()
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_23480\908266201.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = df_selected[col].apply(lambda x: col if x == 'Y' else '')
#   Stocked ppapItem quenchTemper turned sawCut1End sawcutBoth stressRelieved  \
# 0
# 1
# 2
# 3
# 4
#
#   lpAnnealed ground shearOne  ... markHeatBoth annealed pickled normalized  \
# 0                             ...
# 1                             ...
# 2                             ...
# 3                             ...
# 4                             ...
#
#   straighten rollMark roto magnetic ultrasonicTest  eddyCurrent
# 0
# 1                                                   eddyCurrent
# 2
# 3
# 4
#
# [5 rows x 32 columns]

# %%
columns_to_check = ['Stocked', 'ppapItem',
    'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth', 'stressRelieved',
    'lpAnnealed', 'ground', 'shearOne', 'shearBoth', 'spheriodizeAnneal',
    'polished', 'chamfered1End', 'chamferedBoth', 'coldDrawn', 'faceOneEnd',
    'faceBoth', 'deburr', 'demagnetize', 'oneHeatOnly', 'markHeatOne',
    'markHeatBoth', 'annealed', 'pickled', 'normalized', 'straighten',
    'rollMark', 'roto', 'magnetic', 'ultrasonicTest', 'eddyCurrent'
]

# Loop through each column and print value counts
for col in columns_to_check:
    print(f"\nValue counts for column: {col}")
    print(df_selected[col].value_counts(dropna=False))
# Out:
# Value counts for column: Stocked
# Stocked
#            5785
# Stocked     146
# Name: count, dtype: int64
#
# Value counts for column: ppapItem
# ppapItem
#             5798
# ppapItem     133
# Name: count, dtype: int64
#
# Value counts for column: quenchTemper
# quenchTemper
#                 5894
# quenchTemper      37
# Name: count, dtype: int64
#
# Value counts for column: turned
# turned
#           5404
# turned     527
# Name: count, dtype: int64
#
# Value counts for column: sawCut1End
# sawCut1End
#               5800
# sawCut1End     131
# Name: count, dtype: int64
#
# Value counts for column: sawcutBoth
# sawcutBoth
#               5663
# sawcutBoth     268
# Name: count, dtype: int64
#
# Value counts for column: stressRelieved
# stressRelieved
#                   5792
# stressRelieved     139
# Name: count, dtype: int64
#
# Value counts for column: lpAnnealed
# lpAnnealed
#               5522
# lpAnnealed     409
# Name: count, dtype: int64
#
# ...

# %%
df_selected.dtypes
# Out:
# matlType               object
# MaterialStatus         object
# Stocked                object
# organizationCode       object
# Grade                  object
# specCode               object
# Shape                  object
# ppapItem               object
# itemType               object
# diameterMaximum       float64
# diameterMininum       float64
# ThicknessMaximum      float64
# WidthMinimum          float64
# crossCornerMaximum    float64
# crossCornerMinimum    float64
# widthMaximum          float64
# widthMinimum          float64
# cornerRadius          float64
# lengthMaximum         float64
# lengthMinimum         float64
# quenchTemper           object
# turned                 object
# sawCut1End             object
# sawcutBoth             object
# stressRelieved         object
# lpAnnealed             object
# ground                 object
# shearOne               object
# shearBoth              object
# spheriodizeAnneal      object
# polished               object
# ...

# %%
# List of target columns
target_columns = [
    'diameterMaximum', 'diameterMininum', 'ThicknessMaximum', 'WidthMinimum',
    'crossCornerMaximum', 'crossCornerMinimum', 'widthMaximum', 'widthMinimum',
    'cornerRadius', 'lengthMaximum', 'lengthMinimum'
]

# Add column name as prefix to each value in those columns
for col in target_columns:
    df_selected[col] = df_selected[col].apply(lambda x: f"{col}: {x}")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_23480\3083836865.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected[col] = df_selected[col].apply(lambda x: f"{col}: {x}")

# %%
df_selected[[
    'diameterMaximum', 'diameterMininum', 'ThicknessMaximum', 'WidthMinimum',
    'crossCornerMaximum', 'crossCornerMinimum', 'widthMaximum', 'widthMinimum',
    'cornerRadius', 'lengthMaximum', 'lengthMinimum'
]]
# Out:
#               diameterMaximum          diameterMininum       ThicknessMaximum  \
# 0        diameterMaximum: 1.5   diameterMininum: 1.498  ThicknessMaximum: 0.0
# 1       diameterMaximum: 1.15   diameterMininum: 1.148  ThicknessMaximum: 0.0
# 2      diameterMaximum: 1.498   diameterMininum: 1.496  ThicknessMaximum: 0.0
# 3      diameterMaximum: 1.139   diameterMininum: 1.137  ThicknessMaximum: 0.0
# 4     diameterMaximum: 0.8125  diameterMininum: 0.8125  ThicknessMaximum: 0.0
# ...                       ...                      ...                    ...
# 5926  diameterMaximum: 0.5156  diameterMininum: 0.5136  ThicknessMaximum: 0.0
# 5927     diameterMaximum: 2.0   diameterMininum: 1.995  ThicknessMaximum: 0.0
# 5928   diameterMaximum: 0.875   diameterMininum: 0.872  ThicknessMaximum: 0.0
# 5929   diameterMaximum: 2.125    diameterMininum: 2.12  ThicknessMaximum: 0.0
# 5930  diameterMaximum: 0.3145   diameterMininum: 0.311  ThicknessMaximum: 0.0
#
# ...

# %%
# Create a new column with list of values in each row
df_selected['row_values'] = df_selected.apply(lambda row: row.tolist(), axis=1)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_23480\2622021549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['row_values'] = df_selected.apply(lambda row: row.tolist(), axis=1)

# %%
df_selected['row_values']
# Out:
# 0       [Manufactured, Active, , ASTM, 1010, Q002, RD,...
# 1       [Manufactured, Active, , ASTM, 1010, Q004, RD,...
# 2       [Manufactured, Active, , ASTM, 1018, Q001, RD,...
# 3       [Manufactured, Active, , ASTM, 1018, Q001, RD,...
# 4       [Manufactured, Active, , ASTM, 1018, Q002, SQ,...
#                               ...
# 5926    [Manufactured, Active, , ASTM, Stressproof(R),...
# 5927    [Manufactured, Active, , ASTM, Stressproof(R),...
# 5928    [Manufactured, Active, , ASTM, Stressproof(R),...
# 5929    [Manufactured, Active, , ASTM, Stressproof(R),...
# 5930    [Manufactured, Active, , ASTM, Type 630, Q001,...
# Name: row_values, Length: 5931, dtype: object

# %%
df_selected['length_row_values'] = df_selected['row_values'].apply(len)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_23480\670563286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['length_row_values'] = df_selected['row_values'].apply(len)

# %%
# Create a new DataFrame from the 'row_values' column
df_list_row_values= pd.DataFrame(df_selected["row_values"])
df_list_row_values
# Out:
#                                              row_values
# 0     [Manufactured, Active, , ASTM, 1010, Q002, RD,...
# 1     [Manufactured, Active, , ASTM, 1010, Q004, RD,...
# 2     [Manufactured, Active, , ASTM, 1018, Q001, RD,...
# 3     [Manufactured, Active, , ASTM, 1018, Q001, RD,...
# 4     [Manufactured, Active, , ASTM, 1018, Q002, SQ,...
# ...                                                 ...
# 5926  [Manufactured, Active, , ASTM, Stressproof(R),...
# 5927  [Manufactured, Active, , ASTM, Stressproof(R),...
# 5928  [Manufactured, Active, , ASTM, Stressproof(R),...
# 5929  [Manufactured, Active, , ASTM, Stressproof(R),...
# 5930  [Manufactured, Active, , ASTM, Type 630, Q001,...
#
# [5931 rows x 1 columns]

# %%
print(df_list_row_values['row_values'].iloc[10])
# Out:
# ['Manufactured', 'Active', '', 'ASTM', '1018', 'Q002', 'FL', '', 'CF Bar', 'diameterMaximum: 0.0', 'diameterMininum: 0.0', 'ThicknessMaximum: 0.75', 'WidthMinimum: 1.75', 'crossCornerMaximum: 0.0', 'crossCornerMinimum: 0.0', 'widthMaximum: 1.75', 'widthMinimum: 1.745', 'cornerRadius: 0.0', 'lengthMaximum: 147.0', 'lengthMinimum: 144.0', '', '', '', '', '', '', '', '', '', '', '', '', '', 'coldDrawn', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']

# %%
# def filter_values(row):
#     return [x for x in row if x not in ['', 0.0, 0, "ThicknessMaximum : 0" ]]

# df_list_row_values['filtered_values'] = df_list_row_values['row_values'].apply(filter_values)


zero_filter_columns = [
    'diameterMaximum', 'diameterMininum', 'ThicknessMaximum', 'WidthMinimum',
    'crossCornerMaximum', 'crossCornerMinimum', 'widthMaximum', 'widthMinimum',
    'cornerRadius', 'lengthMaximum', 'lengthMinimum'
]

def filter_values(row):
    filtered = []
    for x in row:
        if x in ['', 0.0, 0]:
            continue
        skip = False
        for col in zero_filter_columns:
            if x == f"{col}: 0.0" or x == f"{col} : 0.0" or x == f"{col} : 0":  # Handle different spacing
                skip = True
                break
        if not skip:
            filtered.append(x)
    return filtered

# Apply to your DataFrame
df_list_row_values['filtered_values'] = df_list_row_values['row_values'].apply(filter_values)

# %%
df_list_row_values['filtered_values']
# Out:
# 0       [Manufactured, Active, ASTM, 1010, Q002, RD, C...
# 1       [Manufactured, Active, ASTM, 1010, Q004, RD, C...
# 2       [Manufactured, Active, ASTM, 1018, Q001, RD, C...
# 3       [Manufactured, Active, ASTM, 1018, Q001, RD, C...
# 4       [Manufactured, Active, ASTM, 1018, Q002, SQ, H...
#                               ...
# 5926    [Manufactured, Active, ASTM, Stressproof(R), Q...
# 5927    [Manufactured, Active, ASTM, Stressproof(R), Q...
# 5928    [Manufactured, Active, ASTM, Stressproof(R), Q...
# 5929    [Manufactured, Active, ASTM, Stressproof(R), Q...
# 5930    [Manufactured, Active, ASTM, Type 630, Q001, R...
# Name: filtered_values, Length: 5931, dtype: object

# %%
print(df_list_row_values['row_values'].iloc[10])
print(df_list_row_values['filtered_values'].iloc[10])
# Out:
# ['Manufactured', 'Active', '', 'ASTM', '1018', 'Q002', 'FL', '', 'CF Bar', 'diameterMaximum: 0.0', 'diameterMininum: 0.0', 'ThicknessMaximum: 0.75', 'WidthMinimum: 1.75', 'crossCornerMaximum: 0.0', 'crossCornerMinimum: 0.0', 'widthMaximum: 1.75', 'widthMinimum: 1.745', 'cornerRadius: 0.0', 'lengthMaximum: 147.0', 'lengthMinimum: 144.0', '', '', '', '', '', '', '', '', '', '', '', '', '', 'coldDrawn', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Manufactured', 'Active', 'ASTM', '1018', 'Q002', 'FL', 'CF Bar', 'ThicknessMaximum: 0.75', 'WidthMinimum: 1.75', 'widthMaximum: 1.75', 'widthMinimum: 1.745', 'lengthMaximum: 147.0', 'lengthMinimum: 144.0', 'coldDrawn']

# %%
# vectorize using FAISS

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.docstore.document import Document

# Convert each row to string
text_data =  df_list_row_values['filtered_values'].apply(lambda row: ' '.join(str(item) for item in row)).tolist()
metadata_items = df_items_master["item"].tolist()

# %%
# Load HuggingFace Embedding Model

embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_23480\3389071243.py:3: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
embedding_model
# Out:
# HuggingFaceEmbeddings(client=SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# ), model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, multi_process=False, show_progress=False)

# %%
new_docs_semantic = [
    Document(page_content=text, metadata={"Item": item})
    for text, item in zip(text_data, metadata_items)
]

# %%
new_docs_semantic
# Out:
# [Document(metadata={'Item': 116381}, page_content='Manufactured Active ASTM 1010 Q002 RD CF Bar diameterMaximum: 1.5 diameterMininum: 1.498 lengthMaximum: 158.0 lengthMinimum: 156.0'),
#  Document(metadata={'Item': 120863}, page_content='Manufactured Active ASTM 1010 Q004 RD CF Bar diameterMaximum: 1.15 diameterMininum: 1.148 lengthMaximum: 242.0 lengthMinimum: 240.0 coldDrawn eddyCurrent'),
#  Document(metadata={'Item': 118944}, page_content='Manufactured Active ASTM 1018 Q001 RD CF Bar diameterMaximum: 1.498 diameterMininum: 1.496 lengthMaximum: 192.0 lengthMinimum: 192.0 coldDrawn'),
#  Document(metadata={'Item': 108697}, page_content='Manufactured Active ASTM 1018 Q001 RD CF Bar diameterMaximum: 1.139 diameterMininum: 1.137 lengthMaximum: 162.0 lengthMinimum: 162.0 coldDrawn'),
#  Document(metadata={'Item': 120388}, page_content='Manufactured Active ASTM 1018 Q002 SQ HR Bar diameterMaximum: 0.8125 diameterMininum: 0.8125 lengthMaximum: 374.0 lengthMinimum: 374.0'),
# ...

# %%
vectorstore_semantic = FAISS.from_documents(new_docs_semantic, embedding_model)

# %%
vectorstore_semantic

# %%
def generate_values_string(filled_values: dict) -> str:
    
    keys = [
    'matlType', 'MaterialStatus', 'Stocked', 'organizationCode', 'Grade',
    'specCode', 'Shape', 'ppapItem', 'itemType', 'diameterMaximum',
    'diameterMininum', 'ThicknessMaximum', 'WidthMinimum',
    'crossCornerMaximum', 'crossCornerMinimum', 'widthMaximum',
    'widthMinimum', 'cornerRadius', 'lengthMaximum', 'lengthMinimum',
    'quenchTemper', 'turned', 'sawCut1End', 'sawcutBoth', 'stressRelieved',
    'lpAnnealed', 'ground', 'shearOne', 'shearBoth', 'spheriodizeAnneal',
    'polished', 'chamfered1End', 'chamferedBoth', 'coldDrawn', 'faceOneEnd',
    'faceBoth', 'deburr', 'demagnetize', 'oneHeatOnly', 'markHeatOne',
    'markHeatBoth', 'annealed', 'pickled', 'normalized', 'straighten',
    'rollMark', 'roto', 'magnetic', 'ultrasonicTest', 'eddyCurrent'
    ]

    # Step 1: Create a base dict with empty values
    empty_dict = {key: '' for key in keys}

    # Step 2: Merge the filled values
    final_dict = {**empty_dict, **filled_values}

    # Step 3: Convert all values to string and join them
    all_values_str = ', '.join(str(value) for value in final_dict.values())

    return all_values_str

# %% [markdown]
# #### Test case :  Item Master

# %%
# # item = 113422

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',
    'Grade': '4142SE',
    'specCode' : 'Q002',
    'Shape' : 'RD',
    'itemType' : 'CF Bar',
    'diameterMaximum' : 0.375,
    'diameterMininum' : 0.372,
    'lengthMaximum' : 146,
    'lengthMinimum' : 144
}


result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  Manufactured, Active, , ASTM, 4142SE, Q002, RD, , CF Bar, 0.375, 0.372, , , , , , , , 146, 144, , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
#
#
# Item: 124651
# Score: 0.5632312297821045
# Text: Manufactured Active ASTM 8620H Q002 RD CF Bar diameterMaximum: 1.75 diameterMininum: 1.746 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 115744
# Score: 0.5653741359710693
# Text: Manufactured Active ASTM 1137/1141 Q003 RD CF Bar diameterMaximum: 1.625 diameterMininum: 1.621 lengthMaximum: 123.0 lengthMinimum: 122.0 coldDrawn
# ---
# Item: 109066
# Score: 0.5667009949684143
# Text: Manufactured Active ASTM 1151 Q002 RD CF Bar diameterMaximum: 0.6562 diameterMininum: 0.6532 lengthMaximum: 149.0 lengthMinimum: 148.0 coldDrawn
# ---
# Item: 119349
# Score: 0.5678266286849976
# Text: Manufactured Active ASTM 1045 Q029 RD CF Bar diameterMaximum: 1.75 diameterMininum: 1.746 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 122522
# ...

# %% [markdown]
# ### Test case: PO Description

# %%
# Steel 1144 Round .663" Cold Finished

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',
    'Grade': '1144',
    'specCode' : 'Q002',
    'Shape' : 'Round',
    'itemType' : 'CF Bar',
    # 'diameterMaximum' : 0.375,
    # 'diameterMininum' : 0.372,
    'lengthMaximum' : 0.663,
    # 'lengthMinimum' : 144
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  1144, Round, , , , Manufactured, Active, ASTM, Q002, CF Bar, 0.663
#
#
# Item: 109066
# Score: 0.40553706884384155
# Text: Manufactured Active ASTM 1151 Q002 RD CF Bar diameterMaximum: 0.6562 diameterMininum: 0.6532 lengthMaximum: 149.0 lengthMinimum: 148.0 coldDrawn
# ---
# Item: 109033
# Score: 0.4056951403617859
# Text: Manufactured Active ASTM 1144 Q020 RD CF Bar diameterMaximum: 1.625 diameterMininum: 1.621 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 119771
# Score: 0.4064085781574249
# Text: Manufactured Active ASTM 1141 Q005 RD CF Bar diameterMaximum: 1.625 diameterMininum: 1.621 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 113343
# Score: 0.40647244453430176
# Text: Manufactured Active ASTM 1141 Q003 RD CF Bar diameterMaximum: 1.625 diameterMininum: 1.621 lengthMaximum: 246.0 lengthMinimum: 246.0 coldDrawn
# ---
# Item: 109034
# Score: 0.40675145387649536
# ...

# %%
# Steel 1144 Round .663" Cold Finished

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',
    'Grade': '1144',
    'specCode' : 'Q002',
    'Shape' : 'Round',
    'itemType' : 'CF Bar',
    # 'diameterMaximum' : 0.375,
    # 'diameterMininum' : 0.372,
    'lengthMaximum' : 0.663,
    # 'lengthMinimum' : 144
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  Manufactured, Active, , ASTM, 1144, Q002, Round, , CF Bar, , , , , , , , , , 0.663, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
#
#
# Item: 115744
# Score: 0.5669384002685547
# Text: Manufactured Active ASTM 1137/1141 Q003 RD CF Bar diameterMaximum: 1.625 diameterMininum: 1.621 lengthMaximum: 123.0 lengthMinimum: 122.0 coldDrawn
# ---
# Item: 109066
# Score: 0.5674648284912109
# Text: Manufactured Active ASTM 1151 Q002 RD CF Bar diameterMaximum: 0.6562 diameterMininum: 0.6532 lengthMaximum: 149.0 lengthMinimum: 148.0 coldDrawn
# ---
# Item: 122522
# Score: 0.5698849558830261
# Text: Manufactured Active ASTM 1137 Q006 RD CF Bar diameterMaximum: 1.875 diameterMininum: 1.871 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 127227
# Score: 0.5708879232406616
# Text: Manufactured Active ASTM 1141 Q016 RD CF Bar diameterMaximum: 1.875 diameterMininum: 1.871 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 124651
# ...

# %%
# STEEL 1.1875 ROUND 12L14 12' BAR

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',
    'Grade': '12L14',
    'Shape' : 'Round',
    # 'itemType' : 'CF Bar',
    # 'diameterMaximum' : 0.375,
    'diameterMininum' : 1.1875,
    'lengthMaximum' : 0.12,
    # 'lengthMinimum' : 144
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  Manufactured, Active, , ASTM, 12L14, , Round, , , , 1.1875, , , , , , , , 0.12, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
#
#
# Item: 129491
# Score: 0.8025141358375549
# Text: Manufactured Active ASTM 1141 Q014 RD CF Bar diameterMaximum: 1.875 diameterMininum: 1.875 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 109891
# Score: 0.8025476932525635
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 1.875 diameterMininum: 1.871 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn rollMark
# ---
# Item: 116500
# Score: 0.8048018217086792
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 1.75 diameterMininum: 1.746 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn rollMark
# ---
# Item: 112985
# Score: 0.8065348863601685
# Text: Manufactured Active ASTM 12L14 Q012 RD CF Bar diameterMaximum: 1.125 diameterMininum: 1.123 lengthMaximum: 144.0 lengthMinimum: 144.0 coldDrawn
# ---
# ...

# %%
# 3/4" Hex 12L14 Steel Saw Cut 2 ends

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': ' 12L14',
    'Shape' : 'Hex',
    # 'diameterMaximum' : 0.375,
    # 'diameterMininum' : 1.1875,
    'lengthMaximum' : 0.75,
    # 'lengthMinimum' : 144,
    "sawcutBoth" : "sawcutBoth",
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->   12L14, Hex, , , , Manufactured, Active, ASTM, 0.75, sawcutBoth
#
#
# Item: 125386
# Score: 0.6561952829360962
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 2.625 diameterMininum: 2.62 lengthMaximum: 26.0 lengthMinimum: 24.0 sawcutBoth coldDrawn
# ---
# Item: 121912
# Score: 0.6611574292182922
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 1.25 diameterMininum: 1.247 lengthMaximum: 145.0 lengthMinimum: 144.0 sawCut1End coldDrawn
# ---
# Item: 116542
# Score: 0.6635724306106567
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 0.75 diameterMininum: 0.748 lengthMaximum: 146.0 lengthMinimum: 144.0 sawcutBoth coldDrawn
# ---
# Item: 119655
# Score: 0.663894772529602
# Text: Manufactured Active ASTM 12L14 Q003 HEX CF Bar diameterMaximum: 2.0 diameterMininum: 1.996 cornerRadius: 0.063 lengthMaximum: 146.0 lengthMinimum: 143.0 sawcutBoth coldDrawn
# ---
# Item: 121019
# Score: 0.6644033193588257
# ...

# %%
# 3/4" Hex 12L14 Steel Saw Cut 2 ends

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': ' 12L14',
    'Shape' : 'Hex',
    # 'diameterMaximum' : 0.375,
    # 'diameterMininum' : 1.1875,
    'lengthMaximum' : 0.75,
    # 'lengthMinimum' : 144,
    "sawcutBoth" : "sawcutBoth",
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  Manufactured, Active, , ASTM,  12L14, , Hex, , , , , , , , , , , , 0.75, , , , , sawcutBoth, , , , , , , , , , , , , , , , , , , , , , , , , ,
#
#
# Item: 127959
# Score: 0.806883692741394
# Text: Manufactured Active ASTM 1215 Q003 HEX CF Bar diameterMaximum: 2.0 diameterMininum: 1.996 lengthMaximum: 147.0 lengthMinimum: 141.0 sawcutBoth coldDrawn
# ---
# Item: 127916
# Score: 0.8146534562110901
# Text: Manufactured Active ASTM 1117 Q008 HEX CF Bar diameterMaximum: 1.375 diameterMininum: 1.372 lengthMaximum: 144.0 lengthMinimum: 144.0 sawcutBoth coldDrawn
# ---
# Item: 124029
# Score: 0.8227764368057251
# Text: Manufactured Active ASTM 1215 Q043 HEX CF Bar diameterMaximum: 1.0 diameterMininum: 0.997 lengthMaximum: 75.0 lengthMinimum: 69.0 sawcutBoth coldDrawn
# ---
# Item: 115738
# Score: 0.8238787651062012
# ...

# %%
# STEEL 0.6250 HEX-SHARP 1215 12' BAR

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '1215',
    'Shape' : 'HEX-SHARP',
    'diameterMaximum' : 0.6250,
    'lengthMaximum' : 12,
    'lengthMinimum' : 12,
}


result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  1215, HEX-SHARP, 0.625, , , Manufactured, Active, ASTM, 12, 12
#
#
# Item: 121104
# Score: 0.782106876373291
# Text: Manufactured Active ASTM 1215 Q001 HEX HR Bar diameterMaximum: 2.5625 diameterMininum: 2.5625 lengthMaximum: 421.0 lengthMinimum: 421.0
# ---
# Item: 123082
# Score: 0.783898651599884
# Text: Manufactured Active ASTM 1215 Q003 HEX CF Bar diameterMaximum: 2.125 diameterMininum: 2.121 cornerRadius: 0.063 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn rollMark
# ---
# Item: 123572
# Score: 0.783898651599884
# Text: Manufactured Active ASTM 1215 Q003 HEX CF Bar diameterMaximum: 2.125 diameterMininum: 2.121 cornerRadius: 0.063 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn rollMark
# ---
# Item: 126136
# Score: 0.783898651599884
# Text: Manufactured Active ASTM 1215 Q003 HEX CF Bar diameterMaximum: 2.125 diameterMininum: 2.121 cornerRadius: 0.063 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn rollMark
# ---
# Item: 125683
# ...

# %%
# Steel 1144 Round .663" Cold Finished

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '1144',
    'Shape' : 'Round',
    'itemType' : 'Cold Finished',

    'lengthMaximum' : 0.65,
    'lengthMinimum' : 0.663,
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  1144, Round, , , , Manufactured, Active, ASTM, Cold Finished, 0.65, 0.663
#
#
# Item: 119446
# Score: 0.7228169441223145
# Text: Manufactured Active ASTM 1141 Q005 RD CF Bar diameterMaximum: 0.7495 diameterMininum: 0.7485 lengthMaximum: 146.0 lengthMinimum: 144.0 ground polished coldDrawn
# ---
# Item: 129491
# Score: 0.7430105209350586
# Text: Manufactured Active ASTM 1141 Q014 RD CF Bar diameterMaximum: 1.875 diameterMininum: 1.875 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 116435
# Score: 0.7434837222099304
# Text: Manufactured Active ASTM 416 Q001 RD Stainless diameterMaximum: 0.7505 diameterMininum: 0.7495 lengthMaximum: 146.0 lengthMinimum: 144.0 ground polished coldDrawn
# ---
# Item: 109066
# Score: 0.7455142736434937
# Text: Manufactured Active ASTM 1151 Q002 RD CF Bar diameterMaximum: 0.6562 diameterMininum: 0.6532 lengthMaximum: 149.0 lengthMinimum: 148.0 coldDrawn
# ---
# Item: 112747
# Score: 0.7460840940475464
# ...

# %%
# 1-1/4" Round 1215 Steel 

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '1215',
    'specCode' : '',
    'Shape' : 'Round',
    'itemType' : '',
    'diameterMaximum' : '',
    'diameterMininum' : '',
    'lengthMaximum' : 1.25 ,
    'lengthMinimum' : 1.25 
}



result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  1215, Round, , , , Manufactured, Active, ASTM, 1.25, 1.25
#
#
# Item: 124659
# Score: 0.6618129014968872
# Text: Manufactured Active ASTM 1215 Q001 SQ HR Bar diameterMaximum: 1.1875 diameterMininum: 1.1875 lengthMaximum: 399.0 lengthMinimum: 397.0
# ---
# Item: 109870
# Score: 0.6640095710754395
# Text: Manufactured Active ASTM 1215 Q001 RD HR Bar diameterMaximum: 1.3125 diameterMininum: 1.3125 lengthMaximum: 403.0 lengthMinimum: 401.0
# ---
# Item: 127375
# Score: 0.6661535501480103
# Text: Manufactured Active ASTM 1215 Q001 SQ HR Bar diameterMaximum: 1.25 diameterMininum: 1.25 lengthMaximum: 399.0 lengthMinimum: 397.0
# ---
# Item: 120193
# Score: 0.670730471611023
# Text: Manufactured Active ASTM 1215 Q011 RD CF Bar diameterMaximum: 1.0625 diameterMininum: 1.0605 lengthMaximum: 212.0 lengthMinimum: 210.0 coldDrawn
# ---
# Item: 124660
# Score: 0.6724745035171509
# ...

# %%
# M22500SRL14 2-1/4" STEEL RD 12L14

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '12L14',
    'specCode' : '',
    'Shape' : 'RD',
    'itemType' : '',
    'diameterMaximum' : 2.25,
    'diameterMininum' : 2.25,
    'lengthMaximum' : '',
    'lengthMinimum' : ''
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  12L14, RD, 2.25, 2.25, , Manufactured, Active, ASTM, , , ,
#
#
# Item: 108598
# Score: 0.6667212843894958
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 2.875 diameterMininum: 2.875 lengthMaximum: 423.0 lengthMinimum: 423.0
# ---
# Item: 129083
# Score: 0.6750538945198059
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 1.5625 diameterMininum: 1.5625 lengthMaximum: 277.0 lengthMinimum: 277.0
# ---
# Item: 108654
# Score: 0.6753196716308594
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 2.8125 diameterMininum: 2.8125 lengthMaximum: 421.25 lengthMinimum: 419.0
# ---
# Item: 127347
# Score: 0.6755201816558838
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 2.04688 diameterMininum: 2.04688 lengthMaximum: 398.0 lengthMinimum: 398.0
# ---
# Item: 118361
# Score: 0.6757117509841919
# ...

# %%
# M22500SRL14 2-1/4" STEEL RD 12L14

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '12L14',
    'specCode' : '',
    'Shape' : 'RD',
    'itemType' : '',
    'diameterMaximum' : 2.25,
    'diameterMininum' : 2.25,
    'lengthMaximum' : '',
    'lengthMinimum' : ''
}

result_str = generate_values_string(filled_values)
print('result_str ----> ', result_str)
print("\n")

query = result_str
results = vectorstore_semantic.similarity_search_with_score(query, k=20)
for doc, score in results:
    print(f"Item: {doc.metadata['Item']}")
    print(f"Score: {score}")
    print(f"Text: {doc.page_content}")
    print("---")
# Out:
# result_str ---->  Manufactured, Active, , ASTM, 12L14, , RD, , , 2.25, 2.25, , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,
#
#
# Item: 108598
# Score: 0.7852323055267334
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 2.875 diameterMininum: 2.875 lengthMaximum: 423.0 lengthMinimum: 423.0
# ---
# Item: 129491
# Score: 0.7871888875961304
# Text: Manufactured Active ASTM 1141 Q014 RD CF Bar diameterMaximum: 1.875 diameterMininum: 1.875 lengthMaximum: 147.0 lengthMinimum: 141.0 coldDrawn
# ---
# Item: 127350
# Score: 0.7899610996246338
# Text: Manufactured Active ASTM 12L14 Q001 RD HR Bar diameterMaximum: 1.8125 diameterMininum: 1.8125 lengthMaximum: 406.0 lengthMinimum: 406.0
# ---
# Item: 113301
# Score: 0.7904402017593384
# Text: Manufactured Active ASTM 1141 Q001 RD HR Bar diameterMaximum: 2.0625 diameterMininum: 2.0625 lengthMaximum: 467.0 lengthMinimum: 238.0
# ---
# Item: 125237
# Score: 0.7917267084121704
# ...

# %%
# 1-1/8" RD 12L14 CF Steel
# color code bar ends white
# Certifications Required
# 20361-FS15 1-3/4E

filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '12L14',
    'Shape' : 'RD',
    'itemType' : 'CF',
    'diameterMaximum' : ,
    'diameterMininum' : ,
    'lengthMaximum' : 1.125 ,
    'lengthMinimum' : 
}

# %%
#

# %%
filled_values = {
    'matlType': 'Manufactured',
    'MaterialStatus': 'Active' ,
    'organizationCode' : 'ASTM',

    'Grade': '',
    'specCode' : '',
    'Shape' : '',
    'itemType' : '',
    'diameterMaximum' : ,
    'diameterMininum' : ,
    'lengthMaximum' : ,
    'lengthMinimum' : 
}
